# %% [markdown]
# ## Part 1: Customer Segmentation Report
#
# The main bulk of your analysis will come in this part of the project. Here, you should use unsupervised learning techniques to describe the relationship between the demographics of the company's existing customers and the general population of Germany. By the end of this part, you should be able to describe parts of the general population that are more likely to be part of the mail-order company's main customer base, and which parts of the general population are less so.

# %% [markdown]
# 1. **Univariate analysis** Performed a Chi-squared and produced Cramer's V for each of the categorical fields present in the data between the Customers population and the Germany population. I will present the top columns in the blog.
#
#     Refs:
#     <br> http://rinterested.github.io/statistics/tests_of_proportions.html
#
#     <br>
# 2. **Clustering** Using kmodes clustering which is similar to kmeans but using the mode instead of mean because the data is categorical.
#     <br> Test out different No. of Clusters using Elbow method. Following:
#     <br> https://medium.com/geekculture/the-k-modes-as-clustering-algorithm-for-categorical-data-type-bcde8f95efd7
#     <br> Build a Cluster with optimal number of clusters then visualise:
#     <br>https://www.kaggle.com/code/ashydv/bank-customer-clustering-k-modes-clustering/notebook
#
#     Using Stratified sample: Customers and Germany (random sample with same volume as Customers) and build Clusters then look at the proportion of Customers in each Cluster and look at Cramer's V as a measure of feature importance.

# %% [markdown]
# #### Install packages

# %%
# !pip install plotnine
# Out:
# Looking in indexes: https://pypi.org/simple, https://pip.repos.neuron.amazonaws.com
# Collecting plotnine
#   Downloading plotnine-0.8.0-py3-none-any.whl (4.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.7/4.7 MB 24.3 MB/s eta 0:00:00:00:01
# Requirement already satisfied: pandas>=1.1.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.8/site-packages (from plotnine) (1.3.4)
# Requirement already satisfied: numpy>=1.19.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.8/site-packages (from plotnine) (1.20.3)
# Requirement already satisfied: statsmodels>=0.12.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.8/site-packages (from plotnine) (0.13.1)
# Requirement already satisfied: matplotlib>=3.1.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.8/site-packages (from plotnine) (3.5.0)
# Collecting mizani>=0.7.3
#   Downloading mizani-0.7.4-py3-none-any.whl (63 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.7/63.7 KB 18.7 MB/s eta 0:00:00
# Requirement already satisfied: scipy>=1.5.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.8/site-packages (from plotnine) (1.5.3)
# Collecting descartes>=1.1.0
#   Downloading descartes-1.1.0-py3-none-any.whl (5.8 kB)
# Requirement already satisfied: patsy>=0.5.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.8/site-packages (from plotnine) (0.5.2)
# Requirement already satisfied: cycler>=0.10 in /home/ec2-user/anaconda3/envs/python3/lib/python3.8/site-packages (from matplotlib>=3.1.1->plotnine) (0.11.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.8/site-packages (from matplotlib>=3.1.1->plotnine) (3.0.6)
# Requirement already satisfied: pillow>=6.2.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.8/site-packages (from matplotlib>=3.1.1->plotnine) (9.0.1)
# Requirement already satisfied: packaging>=20.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.8/site-packages (from matplotlib>=3.1.1->plotnine) (21.3)
# Requirement already satisfied: python-dateutil>=2.7 in /home/ec2-user/anaconda3/envs/python3/lib/python3.8/site-packages (from matplotlib>=3.1.1->plotnine) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.8/site-packages (from matplotlib>=3.1.1->plotnine) (1.3.2)
# Requirement already satisfied: fonttools>=4.22.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.8/site-packages (from matplotlib>=3.1.1->plotnine) (4.28.2)
# Collecting pandas>=1.1.0
#   Downloading pandas-1.4.2-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.7/11.7 MB 114.8 MB/s eta 0:00:0000:0100:01
# Collecting palettable
#   Downloading palettable-3.3.0-py2.py3-none-any.whl (111 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 111.8/111.8 KB 34.3 MB/s eta 0:00:00
# Requirement already satisfied: pytz>=2020.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.8/site-packages (from pandas>=1.1.0->plotnine) (2021.3)
# Requirement already satisfied: six in /home/ec2-user/anaconda3/envs/python3/lib/python3.8/site-packages (from patsy>=0.5.1->plotnine) (1.16.0)
# Installing collected packages: palettable, pandas, mizani, descartes, plotnine
#   Attempting uninstall: pandas
#     Found existing installation: pandas 1.3.4
#     Uninstalling pandas-1.3.4:
#       Successfully uninstalled pandas-1.3.4
# Successfully installed descartes-1.1.0 mizani-0.7.4 palettable-3.3.0 pandas-1.4.2 plotnine-0.8.0
# WARNING: You are using pip version 22.0.4; however, version 22.1.2 is available.
# You should consider upgrading via the '/home/ec2-user/anaconda3/envs/python3/bin/python -m pip install --upgrade pip' command.

# %%
# import libraries here; add more as necessary
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import itertools
from plotnine import *
import plotnine

import time
import datetime

# Import module for k-modes cluster
import scipy.stats as stats
from sklearn.model_selection import train_test_split 
from sklearn.ensemble import RandomForestClassifier 
from sklearn.model_selection import GridSearchCV

# magic word for producing visualizations in notebook
# %matplotlib inline
# Use the theme of ggplot
plt.style.use('ggplot')

pd.set_option('display.max_rows', 999)
pd.set_option('display.max_columns', 999)
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
# !pip install kmodes
# Out:
# Looking in indexes: https://pypi.org/simple, https://pip.repos.neuron.amazonaws.com
# Collecting kmodes
#   Downloading kmodes-0.12.1-py2.py3-none-any.whl (20 kB)
# Requirement already satisfied: scikit-learn>=0.22.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.8/site-packages (from kmodes) (1.0.1)
# Requirement already satisfied: scipy>=0.13.3 in /home/ec2-user/anaconda3/envs/python3/lib/python3.8/site-packages (from kmodes) (1.5.3)
# Requirement already satisfied: joblib>=0.11 in /home/ec2-user/anaconda3/envs/python3/lib/python3.8/site-packages (from kmodes) (1.1.0)
# Requirement already satisfied: numpy>=1.10.4 in /home/ec2-user/anaconda3/envs/python3/lib/python3.8/site-packages (from kmodes) (1.20.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.8/site-packages (from scikit-learn>=0.22.0->kmodes) (3.0.0)
# Installing collected packages: kmodes
# Successfully installed kmodes-0.12.1
# WARNING: You are using pip version 22.0.4; however, version 22.1.2 is available.
# You should consider upgrading via the '/home/ec2-user/anaconda3/envs/python3/bin/python -m pip install --upgrade pip' command.

# %%
from kmodes.kmodes import KModes

# %% [markdown]
# #### Read in Data and Prep

# %%
# Classify columns

# Numeric
list_numeric  = [
    'ANZ_HH_TITEL'
    ,'ANZ_PERSONEN'
#     ,'ANZ_TITEL'
    , 'MIN_GEBAEUDEJAHR' # This is year so needs to be recoded to Time since
    ]

# greater than 100 levels - likely numeric
list_large_lvls  = [
    'LNR'                            
    ,'EINGEFUEGT_AM'                    
    ,'KBA13_ANZAHL_PKW'                 
    ,'ANZ_HAUSHALTE_AKTIV'               
    ,'ANZ_STATISTISCHE_HAUSHALTE'        
    ,'GEBURTSJAHR'     
    ]

# fields with large number of missings
list_missing  = [
'ALTER_KIND4'                    
,'ALTER_KIND3'                   
,'TITEL_KZ'                       
,'ALTER_KIND2'                  
,'ALTER_KIND1'                  
,'KK_KUNDENTYP'                
,'KBA05_BAUMAX'                  
,'AGER_TYP'                      
,'EXTSEL992'                     
,'ALTER_HH'                      
,'W_KEIT_KIND_HH' 
  ]

# Columns with single level with my that 98% of customers in 1 of the levels. Based on clean data after removing 05/13, Na rows
list_high_sing_lvl = [
'ANZ_TITEL'
,'D19_TELKO_ONLINE_DATUM'
,'D19_TELKO_ONLINE_QUOTE_12'
,'D19_VERSI_ONLINE_DATUM'
,'D19_VERSI_ONLINE_QUOTE_12'
,'DSL_FLAG'
,'SOHO_KZ'
]

# %%
# labels for printing graphs
labels = pd.read_csv('labels.csv', dtype={'level': 'object'})
# column names
labels_col_names = labels[['field', 'desc']].drop_duplicates()
dict_col_names = labels_col_names.set_index('field').to_dict()['desc']

# %%
labels_col_names
# Out:
#                      field                                               desc
# 0            D19_KONSUMTYP                       Consumption type (Household)
# 7            FINANZ_SPARER                               Money saver (Person)
# 12          FINANZ_ANLEGER                                  Investor (Person)
# 17               FINANZTYP                            Financial Type (Person)
# 23          LP_STATUS_FEIN                             Social Status (Person)
# 33              SEMIO_LUST                           Person is sensual minded
# 40      HH_EINKOMMEN_SCORE                              Household net income
# 46   FINANZ_UNAUFFAELLIGER            Person financial typology: unremarkable
# 51          WOHNDAUER_2008                                Length of residence
# 60         LP_FAMILIE_GROB                                        Family type
# 70               ANREDE_KZ                                             gender
# 72        FINANZ_VORSORGER                    financial typology: be prepared
# 77          RETOURTYP_BK_S                                        return type
# 82              SEMIO_VERT  Affinity indicating in what way the person is ...
# 89           CJT_GESAMTTYP                          customer journey typology
# 95           KBA13_SITZE_5  number of cars with less than 5 seats in the PLZ8
# 101                 ARBEIT  share of unemployed in relation to the county ...
# 106              KBA13_BMW                       share of BMW within the PLZ8
# 112               PLZ8_GBZ                number of buildings within the PLZ8
# 117             PLZ8_ANTG2            number of 3-5 family houses in the PLZ8
# 122            KONSUMNAEHE    distance from a building to PoS (Point of Sale)
# 129          KBA13_KMH_140  share of cars with max speed between 110 km/h ...
# 135        KBA13_HALTER_55  share of car owners between 51 and 55 within t...

# %%
def data_types(customers_csv, list_large_lvls, list_numeric):
    """
    Load in customers data and creates a dictionary with the columns that should be coded as object. 
    """
    
    all_columns = pd.read_csv(customers_csv, nrows=0 , sep=';').columns.tolist()

    object_vars = list(set(all_columns) - set(list_large_lvls) - set(list_numeric))

    dic_dtype = {}
    for var in object_vars:
        dic_dtype.update({var: 'object'})
        
    return dic_dtype

dic_dtype = data_types('customers_FR.csv', list_large_lvls
                      , list_numeric )

# %%
customers_FR = pd.read_csv("customers_FR.csv" ,
                       dtype=dic_dtype
                      )

# %%
Germany_samp = pd.read_csv("Germany_samp.csv" ,
                       dtype=dic_dtype                      )

# %%
# germany_FR = pd.read_csv("germany_FR.csv" ,
#                       dtype=dic_dtype
#                      )      

germany_FR = Germany_samp

# %%
# Needed because Index is output
customers_FR.drop(columns=['Unnamed: 0'], inplace=True)
Germany_samp.drop(columns=['Unnamed: 0'], inplace=True)
# germany_FR.drop(columns=['Unnamed: 0'], inplace=True)

# %% [markdown]
# ### 1. Univariate Analysis

# %%
# https://www.kaggle.com/code/phaethonprime/eda-and-logistic-regression/notebook
def cramers_corrected_stat(conting):
    """ calculate Cramers V statistic for categorical-categorical association.
        uses correction from Bergsma and Wicher, 
        Journal of the Korean Statistical Society 42 (2013): 323-328
    """
    chi2 = stats.chi2_contingency(conting)[0]
    n = conting.sum().sum()
    phi2 = chi2/n
    r,k = conting.shape
    phi2corr = max(0, phi2 - ((k-1)*(r-1))/(n-1))    
    rcorr = r - ((r-1)**2)/(n-1)
    kcorr = k - ((k-1)**2)/(n-1)
    return np.sqrt(phi2corr / min( (kcorr-1), (rcorr-1))) , min((kcorr-1), (rcorr-1))

# %%
# Columns to run the chi-squared test on 
columns_chisq = list(set(all_columns_FR) - set(not_in_ger) )

# Set-up empty dataframe to append results
chisq_output = pd.DataFrame(columns = ['Var', 'dof'])

for col in columns_chisq:
    
    # Prep data
    obs_customers = customers_FR[col].value_counts().rename_axis('unique_values').reset_index(name='obs_customers')
    obs_germany = germany_FR[col].value_counts().rename_axis('unique_values').reset_index(name='obs_germany')
    observed = pd.merge(obs_customers,obs_germany, how='outer', on='unique_values').fillna(0)
    
    cramer, dof = cramers_corrected_stat(observed[['obs_customers','obs_germany']])

    chisq_output = chisq_output.append({'Var': col,
                                       'dof': dof,
                                        'cramer': cramer
                                       }, ignore_index=True)
# Out:
# /tmp/ipykernel_13165/243098895.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# /tmp/ipykernel_13165/243098895.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# /tmp/ipykernel_13165/243098895.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# /tmp/ipykernel_13165/243098895.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# /tmp/ipykernel_13165/243098895.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# /tmp/ipykernel_13165/243098895.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# /tmp/ipykernel_13165/243098895.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# /tmp/ipykernel_13165/243098895.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# /tmp/ipykernel_13165/243098895.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# /tmp/ipykernel_13165/243098895.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# /tmp/ipykernel_13165/243098895.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# /tmp/ipykernel_13165/243098895.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# /tmp/ipykernel_13165/243098895.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# /tmp/ipykernel_13165/243098895.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# /tmp/ipykernel_13165/243098895.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# /tmp/ipykernel_13165/243098895.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# /tmp/ipykernel_13165/243098895.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# /tmp/ipykernel_13165/243098895.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# /tmp/ipykernel_13165/243098895.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# /tmp/ipykernel_13165/243098895.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# /tmp/ipykernel_13165/243098895.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# /tmp/ipykernel_13165/243098895.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# /tmp/ipykernel_13165/243098895.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# /tmp/ipykernel_13165/243098895.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# /tmp/ipykernel_13165/243098895.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# /tmp/ipykernel_13165/243098895.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# /tmp/ipykernel_13165/243098895.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# /tmp/ipykernel_13165/243098895.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# /tmp/ipykernel_13165/243098895.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# /tmp/ipykernel_13165/243098895.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# /tmp/ipykernel_13165/243098895.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# /tmp/ipykernel_13165/243098895.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# /tmp/ipykernel_13165/243098895.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# /tmp/ipykernel_13165/243098895.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# /tmp/ipykernel_13165/243098895.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# /tmp/ipykernel_13165/243098895.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# /tmp/ipykernel_13165/243098895.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# /tmp/ipykernel_13165/243098895.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# /tmp/ipykernel_13165/243098895.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# /tmp/ipykernel_13165/243098895.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# /tmp/ipykernel_13165/243098895.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# /tmp/ipykernel_13165/243098895.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# /tmp/ipykernel_13165/243098895.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# /tmp/ipykernel_13165/243098895.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# /tmp/ipykernel_13165/243098895.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# /tmp/ipykernel_13165/243098895.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# /tmp/ipykernel_13165/243098895.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# /tmp/ipykernel_13165/243098895.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# /tmp/ipykernel_13165/243098895.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# /tmp/ipykernel_13165/243098895.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# /tmp/ipykernel_13165/243098895.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# /tmp/ipykernel_13165/243098895.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# /tmp/ipykernel_13165/243098895.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# /tmp/ipykernel_13165/243098895.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# /tmp/ipykernel_13165/243098895.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# /tmp/ipykernel_13165/243098895.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# /tmp/ipykernel_13165/243098895.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# /tmp/ipykernel_13165/243098895.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# /tmp/ipykernel_13165/243098895.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# /tmp/ipykernel_13165/243098895.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# /tmp/ipykernel_13165/243098895.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# /tmp/ipykernel_13165/243098895.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# /tmp/ipykernel_13165/243098895.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.

# %%
# chisq_output.sort_values(by=['cramer'], ascending=[False] )
plot_these = list(chisq_output.sort_values(by=['cramer'], ascending=[False] ).head(10)['Var'])
plot_these
# Out:
# ['FINANZ_VORSORGER',
#  'HH_EINKOMMEN_SCORE',
#  'WOHNDAUER_2008',
#  'RETOURTYP_BK_S',
#  'SEMIO_VERT',
#  'LP_FAMILIE_GROB',
#  'KBA13_SITZE_5',
#  'CJT_GESAMTTYP',
#  'KBA13_BMW',
#  'ARBEIT']

# %%
# Read in Labels for graphs
# dict_col_names
# labels

for col in plot_these:
    
    # Prep data - ideally turn these lines into function as repeated above ...
    obs_customers = customers_FR[col].value_counts().rename_axis('unique_values').reset_index(name='obs_customers')
    obs_germany = germany_FR[col].value_counts().rename_axis('unique_values').reset_index(name='obs_germany')
    observed = pd.merge(obs_customers,obs_germany, how='outer', on='unique_values').fillna(0)
    
    # Columns for graphs
    observed["Germany"] = observed["obs_germany"]/observed["obs_germany"].sum()
    observed["Customers"] = observed["obs_customers"]/observed["obs_customers"].sum()
   
    filt_labels = labels[labels['field']==col]
    filt_labels = filt_labels.astype({'level': 'int64'})
    for_plotting = observed.merge(filt_labels, left_on='unique_values', right_on='level', how='left')

    print(col)
    for_plotting.sort_values(by=['unique_values']).plot(x="leveldesc", y=["Customers", "Germany"], kind="barh")
    plt.suptitle(dict_col_names[col], size=16, y=1);      
    plt.ylabel('')
    plt.show()
# Out:
# FINANZ_VORSORGER
# HH_EINKOMMEN_SCORE
# WOHNDAUER_2008
# RETOURTYP_BK_S
# SEMIO_VERT
# LP_FAMILIE_GROB
# KBA13_SITZE_5
# CJT_GESAMTTYP
# KBA13_BMW
# ARBEIT

# %% [markdown]
# ### 2. Clustering

# %%
customers_FR.head()
# Out:
#    Unnamed: 0  KBA13_VORB_0  KBA05_HERST5  KBA13_VORB_2  KBA13_HALTER_55  \
# 0           0             4             2             3                5
# 1           2             4             3             3                3
# 2           4             3             3             3                3
# 3           5             4             3             2                2
# 4           6             3             3             4                3
#
#    D19_VERSAND_ONLINE_QUOTE_12  KBA13_CCM_1800  KBA13_HERST_SONST  \
# 0                            0               3                  3
# 1                            0               2                  3
# 2                           10               0                  3
# 3                            0               2                  2
# 4                            7               3                  2
#
#    LP_FAMILIE_GROB  KBA13_VW  KBA13_NISSAN  CJT_GESAMTTYP  D19_TELKO_DATUM  \
# 0                2         4             3              5               10
# 1                1         3             3              2               10
# 2                5         2             4              6                7
# 3                2         4             3              4               10
# 4                2         3             4              2               10
#
#    KBA13_KW_0_60  KBA13_MAZDA  KBA05_ANTG3  KBA13_HERST_EUROPA  \
# 0              3            3            0                   2
# 1              4            3            0                   4
# 2              4            2            2                   4
# 3              2            2            1                   3
# 4              3            2            0                   3
#
#    FINANZ_VORSORGER      PRODUCT_GROUP  KBA13_KMH_251  KBA13_BJ_2004  \
# 0                 5  COSMETIC_AND_FOOD              1              3
# 1                 5  COSMETIC_AND_FOOD              1              1
# 2                 4               FOOD              1              3
# 3                 5  COSMETIC_AND_FOOD              1              3
# 4                 5  COSMETIC_AND_FOOD              3              3
#
#    KBA13_SEG_KLEINST  KBA13_CCM_3000  KBA13_BMW  KBA13_SITZE_5  KBA13_KW_80  \
# 0                  2               3          5              1            2
# 1                  4               5          4              3            1
# 2                  4               4          3              2            0
# 3                  2               4          4              2            0
# 4                  3               4          4              3            2
#
#    D19_VERSI_OFFLINE_DATUM  KBA13_SEG_OBERKLASSE  KBA13_SEG_UTILITIES  \
# 0                       10                     3                    4
# 1                       10                     1                    3
# 2                       10                     1                    3
# 3                       10                     3                    3
# 4                       10                     3                    3
#
#    KBA13_SEG_WOHNMOBILE  SEMIO_VERT  KBA13_SEG_GELAENDEWAGEN  KBA13_KMH_110  \
# 0                     4           6                        3              2
# 1                     5           3                        4              1
# 2                     3           5                        3              1
# 3                     3           7                        2              1
# 4                     2           6                        4              2
#
#    NATIONALITAET_KZ  KBA13_CCM_1500  KBA13_TOYOTA  KBA05_ANTG4  \
# 0                 1               4             2            0
# 1                 1               1             3            0
# 2                 1               1             3            0
# 3                 1               4             4            0
# 4                 1               4             3            0
#
#    HH_EINKOMMEN_SCORE  KBA13_KRSSEG_VAN  KBA13_KW_90  KBA13_HALTER_20  \
# 0                   1                 2            3                1
# 1                   1                 1            0                3
# 2                   6                 2            3                2
# 3                   1                 2            2                2
# 4                   2                 2            0                2
#
#    KBA13_KW_110  KBA13_KMH_140  KBA13_FORD  PLZ8_GBZ  KBA13_CCM_2500  \
# 0             4              4           3         5               4
# 1             2              5           3         2               2
# 2             2              4           4         3               0
# 3             3              3           2         5               5
# 4             0              4           5         5               4
#
#    WOHNDAUER_2008  D19_BANKEN_ONLINE_DATUM  KBA05_MODTEMP  ONLINE_PURCHASE  \
# 0               9                       10              2                0
# 1               9                       10              3                0
# 2               9                        7              4                0
# 3               9                       10              1                0
# 4               9                       10              4                0
#
#   CUSTOMER_GROUP  ARBEIT  KBA13_HALTER_45  PLZ8_ANTG2  KBA13_FAB_ASIEN  \
# 0    MULTI_BUYER       1                2           3                2
# 1    MULTI_BUYER       3                2           3                3
# 2    MULTI_BUYER       3                5           4                4
# 3    MULTI_BUYER       3                4           3                3
# 4    MULTI_BUYER       2                2           2                1
#
#    RETOURTYP_BK_S  KBA13_SEG_MITTELKLASSE  KBA13_KW_70  REGIOTYP  \
# 0               5                       3            3         1
# 1               5                       2            2         7
# 2               5                       2            3         7
# 3               3                       4            2         3
# 4               5                       2            3         3
#
#    KBA13_HALTER_40  KONSUMNAEHE  KBA13_KRSAQUOT  GEBAEUDETYP  KBA13_OPEL  \
# 0                3            5               3            1           3
# 1                2            1               3            8           1
# 2                2            1               3            3           4
# 3                4            2               5            1           1
# 4                2            4               2            1           3
#
#    D19_VERSI_ANZ_12  KBA13_AUDI  KBA13_HALTER_65
# 0                 0           4                4
# 1                 0           4                3
# 2                 0           2                3
# 3                 0           3                3
# 4                 0           3                3

# %%
all_columns_FR = list(customers_FR.columns)
not_in_ger = ['PRODUCT_GROUP', 'CUSTOMER_GROUP', 'ONLINE_PURCHASE']

# %%
columns_chisq = list(set(all_columns_FR) - set(not_in_ger) )

# %%
# Append Customers with random sample from Germany
# Germany_samp = germany_FR.sample(n = customers_FR.shape[0], random_state = 12345).copy()
Germany_samp['subset'] = 'germany'
cluster_subset = customers_FR[columns_chisq].copy()
cluster_subset['subset'] = 'customer'
combcus_germ = pd.concat([Germany_samp, cluster_subset], axis = 0).reset_index().drop(['index', 'Unnamed: 0', 'Unnamed: 0.1'], axis = 1)
# Drop the extra 3 columns not in Germany

combcus_germ_features = combcus_germ.drop(['subset'], axis = 1)
dfMatrix = combcus_germ_features.values

# %%
combcus_germ_features.head()
# Out:
#    KBA13_VORB_0  KBA05_HERST5  KBA13_VORB_2  KBA13_HALTER_55  \
# 0             4             3             3                3
# 1             3             4             3                4
# 2             3             3             3                3
# 3             3             2             3                4
# 4             2             5             4                3
#
#    D19_VERSAND_ONLINE_QUOTE_12  KBA13_CCM_1800  KBA13_HERST_SONST  \
# 0                           10               0                  3
# 1                           10               3                  3
# 2                           10               4                  2
# 3                            0               3                  2
# 4                            0               2                  4
#
#    LP_FAMILIE_GROB  KBA13_VW  KBA13_NISSAN  CJT_GESAMTTYP  D19_TELKO_DATUM  \
# 0                4         3             5              6               10
# 1                4         3             2              4               10
# 2                5         2             2              5                9
# 3                3         4             3              6                9
# 4                4         2             5              1                9
#
#    KBA13_KW_0_60  KBA13_MAZDA  KBA05_ANTG3  KBA13_HERST_EUROPA  \
# 0              3            2            0                   2
# 1              4            2            3                   4
# 2              3            4            0                   2
# 3              3            2            0                   5
# 4              5            4            0                   3
#
#    FINANZ_VORSORGER  KBA13_KMH_251  KBA13_BJ_2004  KBA13_SEG_KLEINST  \
# 0                 4              3              3                  3
# 1                 4              3              3                  3
# 2                 4              1              3                  2
# 3                 3              1              3                  2
# 4                 1              1              3                  4
#
#    KBA13_CCM_3000  KBA13_BMW  KBA13_SITZE_5  KBA13_KW_80  \
# 0               3          3              2            3
# 1               3          3              3            0
# 2               5          4              3            3
# 3               3          3              3            3
# 4               1          1              5            2
#
#    D19_VERSI_OFFLINE_DATUM  KBA13_SEG_OBERKLASSE  KBA13_SEG_UTILITIES  \
# 0                       10                     4                    2
# 1                       10                     3                    4
# 2                       10                     3                    2
# 3                       10                     0                    4
# 4                       10                     2                    1
#
#    KBA13_SEG_WOHNMOBILE  SEMIO_VERT  KBA13_SEG_GELAENDEWAGEN  KBA13_KMH_110  \
# 0                     3           6                        3              1
# 1                     3           5                        2              2
# 2                     3           7                        4              1
# 3                     3           2                        2              3
# 4                     2           2                        2              3
#
#    NATIONALITAET_KZ  KBA13_CCM_1500  KBA13_TOYOTA  KBA05_ANTG4  \
# 0                 1               2             3            0
# 1                 2               4             3            0
# 2                 2               1             5            0
# 3                 3               3             1            0
# 4                 1               3             3            2
#
#    HH_EINKOMMEN_SCORE  KBA13_KRSSEG_VAN  KBA13_KW_90  KBA13_HALTER_20  \
# 0                   4                 2            2                3
# 1                   6                 2            2                4
# 2                   4                 2            0                2
# 3                   4                 2            3                2
# 4                   6                 1            2                4
#
#    KBA13_KW_110  KBA13_KMH_140  KBA13_FORD  PLZ8_GBZ  KBA13_CCM_2500  \
# 0             3              3           3         5               3
# 1             3              3           3         5               3
# 2             4              4           3         3               4
# 3             3              3           5         5               3
# 4             2              3           3         3               2
#
#    WOHNDAUER_2008  D19_BANKEN_ONLINE_DATUM  KBA05_MODTEMP  ARBEIT  \
# 0               8                        9              3       2
# 1               8                        1              2       2
# 2               9                        5              2       3
# 3               8                        9              4       3
# 4               9                       10              1       5
#
#    KBA13_HALTER_45  PLZ8_ANTG2  KBA13_FAB_ASIEN  RETOURTYP_BK_S  \
# 0                4           3                3               3
# 1                4           3                3               3
# 2                2           3                3               3
# 3                3           2                2               1
# 4                3           3                5               1
#
#    KBA13_SEG_MITTELKLASSE  KBA13_KW_70  REGIOTYP  KBA13_HALTER_40  \
# 0                       2            0         4                4
# 1                       3            0         7                4
# 2                       5            2         2                3
# 3                       3            3         5                4
# 4                       4            3         4                1
#
#    KONSUMNAEHE  KBA13_KRSAQUOT  GEBAEUDETYP  KBA13_OPEL  D19_VERSI_ANZ_12  \
# 0            2               3            1           4                 0
# 1            4               4            8           4                 1
# 2            3               5            1           1                 2
# 3            5               4            8           3                 0
# 4            5               2            1           4                 0
#
#    KBA13_AUDI  KBA13_HALTER_65
# 0           3                4
# 1           3                3
# 2           5                5
# 3           4                2
# 4           1                2

# %%
# Choosing optimal K
start_time = datetime.datetime.now()
print(start_time)  
cost = []
for cluster in range(1, 11):
    kmodes = KModes(n_jobs = -1, n_clusters = cluster, init = 'Huang', random_state = 0)
    kmodes.fit_predict(dfMatrix)
    cost.append(kmodes.cost_)  
    print('Cluster initiation: {}'.format(cluster))
end_time = datetime.datetime.now()
print(end_time)
# Out:
# 2022-06-08 09:38:09.876189
# Cluster initiation: 1
# Cluster initiation: 2
# Cluster initiation: 3
# Cluster initiation: 4
# Cluster initiation: 5
# Cluster initiation: 6
# Cluster initiation: 7
# Cluster initiation: 8
# Cluster initiation: 9
# Cluster initiation: 10
# 2022-06-08 14:25:12.744892

# %%
# Converting the results into a dataframe and plotting them
df_cost = pd.DataFrame({'Cluster': range(1, 11), 'Cost': cost})

# %%
# Data viz
plotnine.options.figure_size = (8, 4.8)
(
    ggplot(data = df_cost)+
    geom_line(aes(x = 'Cluster',
                  y = 'Cost'))+
    geom_point(aes(x = 'Cluster',
                   y = 'Cost'))+
    geom_label(aes(x = 'Cluster',
                   y = 'Cost',
                   label = 'Cluster'),
               size = 10,
               nudge_y = 1000) +
    labs(title = 'Optimal number of cluster with Elbow Method')+
    xlab('Number of Clusters k')+
    ylab('Cost')+
    theme_minimal()
)
# Out:
# <ggplot: (8784535314695)>

# %%
# Fit the cluster
start_time = datetime.datetime.now()
print(start_time)

kmodes2 = KModes(n_jobs = -1, n_clusters = 2, init = 'Huang', random_state = 0)
fitClusters2 = kmodes2.fit_predict(dfMatrix)

end_time = datetime.datetime.now()
print(end_time)
# Out:
# 2022-06-08 14:25:13.188739
# 2022-06-08 14:40:56.817531

# %%
# Fit the cluster
start_time = datetime.datetime.now()
print(start_time)
kmodes = KModes(n_jobs = -1, n_clusters = 6, init = 'Huang', random_state = 0)
fitClusters = kmodes.fit_predict(dfMatrix)
end_time = datetime.datetime.now()
print(end_time)
# Out:
# 2022-06-08 20:22:33.912373
# 2022-06-08 20:53:02.223232

# %%
# Join Features and the prediction (also includes the subset column)
clustersDf = pd.DataFrame(fitClusters)
clustersDf.columns = ['cluster_predicted']

cluster_subset_ind = combcus_germ.reset_index()
combinedDf = pd.concat([clustersDf, cluster_subset_ind], axis = 1).reset_index()
combinedDf = combinedDf.drop(['index', 'level_0'], axis = 1)
combinedDf.head()
# Out:
#    cluster_predicted  KBA13_VORB_0  KBA05_HERST5  KBA13_VORB_2  \
# 0                  0             4             3             3
# 1                  0             3             4             3
# 2                  5             3             3             3
# 3                  2             3             2             3
# 4                  0             2             5             4
#
#    KBA13_HALTER_55  D19_VERSAND_ONLINE_QUOTE_12  KBA13_CCM_1800  \
# 0                3                           10               0
# 1                4                           10               3
# 2                3                           10               4
# 3                4                            0               3
# 4                3                            0               2
#
#    KBA13_HERST_SONST  LP_FAMILIE_GROB  KBA13_VW  KBA13_NISSAN  CJT_GESAMTTYP  \
# 0                  3                4         3             5              6
# 1                  3                4         3             2              4
# 2                  2                5         2             2              5
# 3                  2                3         4             3              6
# 4                  4                4         2             5              1
#
#    D19_TELKO_DATUM  KBA13_KW_0_60  KBA13_MAZDA  KBA05_ANTG3  \
# 0               10              3            2            0
# 1               10              4            2            3
# 2                9              3            4            0
# 3                9              3            2            0
# 4                9              5            4            0
#
#    KBA13_HERST_EUROPA  FINANZ_VORSORGER  KBA13_KMH_251  KBA13_BJ_2004  \
# 0                   2                 4              3              3
# 1                   4                 4              3              3
# 2                   2                 4              1              3
# 3                   5                 3              1              3
# 4                   3                 1              1              3
#
#    KBA13_SEG_KLEINST  KBA13_CCM_3000  KBA13_BMW  KBA13_SITZE_5  KBA13_KW_80  \
# 0                  3               3          3              2            3
# 1                  3               3          3              3            0
# 2                  2               5          4              3            3
# 3                  2               3          3              3            3
# 4                  4               1          1              5            2
#
#    D19_VERSI_OFFLINE_DATUM  KBA13_SEG_OBERKLASSE  KBA13_SEG_UTILITIES  \
# 0                       10                     4                    2
# 1                       10                     3                    4
# 2                       10                     3                    2
# 3                       10                     0                    4
# 4                       10                     2                    1
#
#    KBA13_SEG_WOHNMOBILE  SEMIO_VERT  KBA13_SEG_GELAENDEWAGEN  KBA13_KMH_110  \
# 0                     3           6                        3              1
# 1                     3           5                        2              2
# 2                     3           7                        4              1
# 3                     3           2                        2              3
# 4                     2           2                        2              3
#
#    NATIONALITAET_KZ  KBA13_CCM_1500  KBA13_TOYOTA  KBA05_ANTG4  \
# 0                 1               2             3            0
# 1                 2               4             3            0
# 2                 2               1             5            0
# 3                 3               3             1            0
# 4                 1               3             3            2
#
#    HH_EINKOMMEN_SCORE  KBA13_KRSSEG_VAN  KBA13_KW_90  KBA13_HALTER_20  \
# 0                   4                 2            2                3
# 1                   6                 2            2                4
# 2                   4                 2            0                2
# 3                   4                 2            3                2
# 4                   6                 1            2                4
#
#    KBA13_KW_110  KBA13_KMH_140  KBA13_FORD  PLZ8_GBZ  KBA13_CCM_2500  \
# 0             3              3           3         5               3
# 1             3              3           3         5               3
# 2             4              4           3         3               4
# 3             3              3           5         5               3
# 4             2              3           3         3               2
#
#    WOHNDAUER_2008  D19_BANKEN_ONLINE_DATUM  KBA05_MODTEMP  ARBEIT  \
# 0               8                        9              3       2
# 1               8                        1              2       2
# 2               9                        5              2       3
# 3               8                        9              4       3
# 4               9                       10              1       5
#
#    KBA13_HALTER_45  PLZ8_ANTG2  KBA13_FAB_ASIEN  RETOURTYP_BK_S  \
# 0                4           3                3               3
# 1                4           3                3               3
# 2                2           3                3               3
# 3                3           2                2               1
# 4                3           3                5               1
#
#    KBA13_SEG_MITTELKLASSE  KBA13_KW_70  REGIOTYP  KBA13_HALTER_40  \
# 0                       2            0         4                4
# 1                       3            0         7                4
# 2                       5            2         2                3
# 3                       3            3         5                4
# 4                       4            3         4                1
#
#    KONSUMNAEHE  KBA13_KRSAQUOT  GEBAEUDETYP  KBA13_OPEL  D19_VERSI_ANZ_12  \
# 0            2               3            1           4                 0
# 1            4               4            8           4                 1
# 2            3               5            1           1                 2
# 3            5               4            8           3                 0
# 4            5               2            1           4                 0
#
#    KBA13_AUDI  KBA13_HALTER_65   subset
# 0           3                4  germany
# 1           3                3  germany
# 2           5                5  germany
# 3           4                2  germany
# 4           1                2  germany

# %%
# Find out if there are more customers in a particular Cluster
plt.subplots(figsize = (15,5))
sns.countplot(x=combinedDf['subset'],order=combinedDf['subset'].value_counts().index,hue=combinedDf['cluster_predicted'])
plt.show()

# %%
# Run Chi-squared for feature importance
# Might look into permutation_importance if time
### https://scikit-learn.org/stable/modules/permutation_importance.html#:~:text=The%20permutation%20feature%20importance%20is,model%20depends%20on%20the%20feature.

clus_imp_out = pd.DataFrame(columns = ['Col', 'CramerV'])

for col in columns_chisq:

    cramer, dof = cramers_corrected_stat(pd.crosstab(combinedDf['cluster_predicted'], combinedDf[col]))

    clus_imp_out = clus_imp_out.append({'Col': col,
                                      'CramerV': cramer,
                                      'dof': dof
                                          }, ignore_index=True)
# Out:
# /tmp/ipykernel_13165/1850604987.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# /tmp/ipykernel_13165/1850604987.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# /tmp/ipykernel_13165/1850604987.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# /tmp/ipykernel_13165/1850604987.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# /tmp/ipykernel_13165/1850604987.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# /tmp/ipykernel_13165/1850604987.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# /tmp/ipykernel_13165/1850604987.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# /tmp/ipykernel_13165/1850604987.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# /tmp/ipykernel_13165/1850604987.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# /tmp/ipykernel_13165/1850604987.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# /tmp/ipykernel_13165/1850604987.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# /tmp/ipykernel_13165/1850604987.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# /tmp/ipykernel_13165/1850604987.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# /tmp/ipykernel_13165/1850604987.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# /tmp/ipykernel_13165/1850604987.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# /tmp/ipykernel_13165/1850604987.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# /tmp/ipykernel_13165/1850604987.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# /tmp/ipykernel_13165/1850604987.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# /tmp/ipykernel_13165/1850604987.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# /tmp/ipykernel_13165/1850604987.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# /tmp/ipykernel_13165/1850604987.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# /tmp/ipykernel_13165/1850604987.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# /tmp/ipykernel_13165/1850604987.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# /tmp/ipykernel_13165/1850604987.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# /tmp/ipykernel_13165/1850604987.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# /tmp/ipykernel_13165/1850604987.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# /tmp/ipykernel_13165/1850604987.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# /tmp/ipykernel_13165/1850604987.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# /tmp/ipykernel_13165/1850604987.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# /tmp/ipykernel_13165/1850604987.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# /tmp/ipykernel_13165/1850604987.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# /tmp/ipykernel_13165/1850604987.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# /tmp/ipykernel_13165/1850604987.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# /tmp/ipykernel_13165/1850604987.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# /tmp/ipykernel_13165/1850604987.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# /tmp/ipykernel_13165/1850604987.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# /tmp/ipykernel_13165/1850604987.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# /tmp/ipykernel_13165/1850604987.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# /tmp/ipykernel_13165/1850604987.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# /tmp/ipykernel_13165/1850604987.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# /tmp/ipykernel_13165/1850604987.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# /tmp/ipykernel_13165/1850604987.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# /tmp/ipykernel_13165/1850604987.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# /tmp/ipykernel_13165/1850604987.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# /tmp/ipykernel_13165/1850604987.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# /tmp/ipykernel_13165/1850604987.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# /tmp/ipykernel_13165/1850604987.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# /tmp/ipykernel_13165/1850604987.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# /tmp/ipykernel_13165/1850604987.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# /tmp/ipykernel_13165/1850604987.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# /tmp/ipykernel_13165/1850604987.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# /tmp/ipykernel_13165/1850604987.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# /tmp/ipykernel_13165/1850604987.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# /tmp/ipykernel_13165/1850604987.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# /tmp/ipykernel_13165/1850604987.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# /tmp/ipykernel_13165/1850604987.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# /tmp/ipykernel_13165/1850604987.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# /tmp/ipykernel_13165/1850604987.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# /tmp/ipykernel_13165/1850604987.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# /tmp/ipykernel_13165/1850604987.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# /tmp/ipykernel_13165/1850604987.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# /tmp/ipykernel_13165/1850604987.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# /tmp/ipykernel_13165/1850604987.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#                             Col   CramerV       dof
# 35                   PLZ8_ANTG2  0.299841  3.999933
# 51                     PLZ8_GBZ  0.296097  3.999933
# 26              KBA13_HALTER_55  0.263438  3.999933
# 37                  KONSUMNAEHE  0.234609  4.999895
# 29                KBA13_KMH_140  0.230505  3.999933
# 8            HH_EINKOMMEN_SCORE  0.229092  4.999895
# 58                    KBA13_BMW  0.225873  3.999933
# 56                  KBA05_ANTG4  0.225329  1.999983
# 1               KBA13_HALTER_20  0.209708  3.999933
# 15                       ARBEIT  0.202733  4.999895
# 32         KBA13_SEG_OBERKLASSE  0.200822  4.999895
# 5                KBA13_CCM_1500   0.19469  3.999933
# 22              KBA13_HALTER_40  0.193045  3.999933
# 61              LP_FAMILIE_GROB  0.192195  3.999933
# 16                KBA13_KW_0_60  0.192069  3.999933
# 62               KBA13_CCM_3000  0.190566  4.999895
# 17                     REGIOTYP  0.184374  4.999895
# 43            KBA13_SEG_KLEINST  0.183008  3.999933
# 31               KBA13_KRSAQUOT  0.179164  3.999933
# 14                  KBA05_ANTG3  0.176789  2.999962
# 39                 KBA13_NISSAN  0.168807  3.999933
# 6                    KBA13_OPEL  0.164291  3.999933
# 12      KBA13_SEG_GELAENDEWAGEN  0.162698  3.999933
# 41               RETOURTYP_BK_S  0.162088  3.999933
# 23                KBA13_SITZE_5   0.15897  3.999933
# 4             KBA13_HERST_SONST  0.157227  3.999933
# 47                KBA13_KMH_110  0.157071  1.999983
# 21                   SEMIO_VERT  0.156927  4.999895
# 30                   KBA13_FORD  0.155209  3.999933
# 59              KBA13_HALTER_65  0.147988  3.999933
# 34  D19_VERSAND_ONLINE_QUOTE_12  0.147965  4.999895
# 49                 KBA13_VORB_0  0.144661  3.999933
# 3                KBA13_CCM_2500  0.142958  4.999895
# 10                  GEBAEUDETYP  0.138463  4.999895
# 36                 KBA13_KW_110  0.134771  4.999895
# 18                  KBA13_KW_80  0.131236  4.999895
# 53                KBA05_MODTEMP  0.127269  4.999895
# 25                  KBA13_KW_70  0.126679  4.999895
# 11                KBA13_KMH_251  0.125148  1.999983
# 46                CJT_GESAMTTYP  0.116601  4.999895
# 50                 KBA13_VORB_2  0.106981  3.999933
# 45             KBA13_KRSSEG_VAN  0.106559  2.999962
# 52                   KBA13_AUDI  0.105245  3.999933
# 54                  KBA13_KW_90  0.099928  4.999895
# 44               KBA13_CCM_1800  0.096781  4.999895
# 42                     KBA13_VW  0.092753  3.999933
# 28             FINANZ_VORSORGER  0.087631  3.999933
# 9               KBA13_FAB_ASIEN  0.082494  3.999933
# 48               WOHNDAUER_2008  0.080191  4.999895
# 33                 KBA05_HERST5  0.079872  4.999895
# 27           KBA13_HERST_EUROPA  0.079434  3.999933
# 2                   KBA13_MAZDA  0.078162  3.999933
# 0               KBA13_HALTER_45  0.077745  3.999933
# 20          KBA13_SEG_UTILITIES  0.069738  3.999933
# 57                KBA13_BJ_2004  0.063932  3.999933
# 38         KBA13_SEG_WOHNMOBILE  0.059537  4.999895
# 19       KBA13_SEG_MITTELKLASSE  0.055765  3.999933
# 13                 KBA13_TOYOTA   0.05396  3.999933
# 55             NATIONALITAET_KZ  0.053167  2.999962
# 7               D19_TELKO_DATUM  0.052252  4.999895
# 24             D19_VERSI_ANZ_12   0.04616  4.999895
# 40      D19_BANKEN_ONLINE_DATUM  0.043939  4.999895
# 60      D19_VERSI_OFFLINE_DATUM  0.029528  4.999895

# %%
print_indiv_col = list(clus_imp_out.sort_values(by=['CramerV'], ascending=[False]).head()['Col'])
print_indiv_col
# Out:
# ['PLZ8_ANTG2', 'PLZ8_GBZ', 'KBA13_HALTER_55', 'KONSUMNAEHE', 'KBA13_KMH_140']

# %%
# Plot Features individually 
for col in print_indiv_col:
    plt.subplots(figsize = (15,5))
    sns.countplot(x=combinedDf[col],order=combinedDf[col].value_counts().index,hue=combinedDf['cluster_predicted'])
    plt.show()

# %%
for_plotting
# Out:
#           0         1         2         3         4         5  leveldesc
# 0  0.442403  0.244263  0.138166  0.493037  0.514790  0.158280   very low
# 1  0.126224  0.112946  0.197499  0.132500  0.033913  0.202228        low
# 2  0.175792  0.149033  0.447640  0.151864  0.116074  0.151835    average
# 3  0.162328  0.395320  0.161960  0.155674  0.207649  0.414652       high
# 4  0.093252  0.098438  0.054735  0.066925  0.127574  0.073005  very high

# %%
for col in print_indiv_col:
    heatmap_data_vals = combinedDf.groupby(['cluster_predicted',col])[col].count()/combinedDf.groupby(['cluster_predicted'])[col].count()
    heatmap_data = heatmap_data_vals.unstack().T

    heatmap_data.reset_index()
    filt_labels = labels[labels['field']==col][['level', 'leveldesc']]
    filt_labels = filt_labels.astype({'level': 'int64'})
    heatmap_data
    for_plotting = heatmap_data.merge(filt_labels, left_on=col, right_on='level', how='left').drop('level', axis=1)
    for_plotting.set_index('leveldesc', inplace=True)
    
    plt.style.use("seaborn")
    plt.figure(figsize=(10,10))
    heat_map = sns.heatmap( for_plotting, linewidth = 1 , annot = True)
    plt.suptitle(dict_col_names[col], size=16, y=1);      
    plt.ylabel('')
    
    plt.show()

# %%
filt_labels = labels[labels['field']==col]
filt_labels = filt_labels.astype({'level': 'int64'})
for_plotting = observed.merge(filt_labels, left_on='unique_values', right_on='level', how='left')

# %%
# KBA13_KMH_140

cluster_0 = combinedDf[combinedDf['cluster_predicted'] == 0]

for_plotting.sort_values(by=['unique_values']).plot(x="leveldesc", y=["Customers", "Germany"], kind="barh")
plt.suptitle(dict_col_names[col], size=16, y=1);      
plt.ylabel('')
plt.show()

# %%
# More Customers are in Cluster 3.
# A particular use of this would be to target all non-Customers in Cluster 3, if possible.
# Less Customers in Cluster 1.

# Let's compare Clusters 1 and 3.

# Add the cluster to the dataframe
combcus_germ['Cluster Labels'] = kmodes.labels_

list_col = ['Cluster Labels', 'subset']
cols = [col for col in combcus_germ if col not in list_col]

df_cluster_modes = pd.DataFrame(kmodes.cluster_centroids_
             , columns = cols
            )
# Cluster 0 and 3 only
df_cluster_modes03 = df_cluster_modes.iloc[[0,3]]

# df_cluster_modes03 = df_cluster_modes03.rename(columns = {'index':'Cluster'})
df_cluster_modes03
# Out:
#    KBA13_VORB_0  KBA05_HERST5  KBA13_VORB_2  KBA13_HALTER_55  \
# 0             3             3             3                3
# 3             4             3             3                2
#
#    D19_VERSAND_ONLINE_QUOTE_12  KBA13_CCM_1800  KBA13_HERST_SONST  \
# 0                           10               2                  3
# 3                            0               3                  3
#
#    LP_FAMILIE_GROB  KBA13_VW  KBA13_NISSAN  CJT_GESAMTTYP  D19_TELKO_DATUM  \
# 0                5         3             3              4               10
# 3                5         3             2              4               10
#
#    KBA13_KW_0_60  KBA13_MAZDA  KBA05_ANTG3  KBA13_HERST_EUROPA  \
# 0              3            3            0                   3
# 3              2            3            0                   3
#
#    FINANZ_VORSORGER  KBA13_KMH_251  KBA13_BJ_2004  KBA13_SEG_KLEINST  \
# 0                 5              1              3                  3
# 3                 5              1              3                  2
#
#    KBA13_CCM_3000  KBA13_BMW  KBA13_SITZE_5  KBA13_KW_80  \
# 0               3          3              3            3
# 3               5          5              2            2
#
#    D19_VERSI_OFFLINE_DATUM  KBA13_SEG_OBERKLASSE  KBA13_SEG_UTILITIES  \
# 0                       10                     3                    3
# 3                       10                     5                    3
#
#    KBA13_SEG_WOHNMOBILE  SEMIO_VERT  KBA13_SEG_GELAENDEWAGEN  KBA13_KMH_110  \
# 0                     3           5                        3              1
# 3                     3           7                        3              1
#
#    NATIONALITAET_KZ  KBA13_CCM_1500  KBA13_TOYOTA  KBA05_ANTG4  \
# 0                 1               1             3            0
# 3                 1               1             3            0
#
#    HH_EINKOMMEN_SCORE  KBA13_KRSSEG_VAN  KBA13_KW_90  KBA13_HALTER_20  \
# 0                   1                 2            2                3
# 3                   1                 2            2                2
#
#    KBA13_KW_110  KBA13_KMH_140  KBA13_FORD  PLZ8_GBZ  KBA13_CCM_2500  \
# 0             2              1           3         3               3
# 3             3              1           2         3               5
#
#    WOHNDAUER_2008  D19_BANKEN_ONLINE_DATUM  KBA05_MODTEMP  ARBEIT  \
# 0               9                       10              3       2
# 3               9                       10              1       3
#
#    KBA13_HALTER_45  PLZ8_ANTG2  KBA13_FAB_ASIEN  RETOURTYP_BK_S  \
# 0                3           2                3               3
# 3                3           3                3               5
#
#    KBA13_SEG_MITTELKLASSE  KBA13_KW_70  REGIOTYP  KBA13_HALTER_40  \
# 0                       3            3         6                3
# 3                       3            2         1                3
#
#    KONSUMNAEHE  KBA13_KRSAQUOT  GEBAEUDETYP  KBA13_OPEL  D19_VERSI_ANZ_12  \
# 0            5               3            1           3                 0
# 3            3               3            1           2                 0
#
#    KBA13_AUDI  KBA13_HALTER_65
# 0           3                3
# 3           3                4

# %%
list_cols_1_3 = list(df_cluster_modes03.columns)
# list_cols_1_3 = ['KBA13_VORB_0']

drop_cols = []

for col in list_cols_1_3:
    test = df_cluster_modes03[col].value_counts().rename_axis('unique_values').reset_index(name='counts')
    test2= test[test['counts']!=2]

    if test2.shape[0] == 0:
        drop_cols.append(col)

df_cluster_modes03.drop(columns=drop_cols, inplace=True)
df_cluster_modes03.shape
# Out:
# /tmp/ipykernel_13165/3459520773.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# (2, 26)

# %%
df_cluster_modes03.T
# Pick out a few to comment on.
# Out:
#                               0  3
# KBA13_VORB_0                  3  4
# KBA13_HALTER_55               3  2
# D19_VERSAND_ONLINE_QUOTE_12  10  0
# KBA13_CCM_1800                2  3
# KBA13_NISSAN                  3  2
# KBA13_KW_0_60                 3  2
# KBA13_SEG_KLEINST             3  2
# KBA13_CCM_3000                3  5
# KBA13_BMW                     3  5
# KBA13_SITZE_5                 3  2
# KBA13_KW_80                   3  2
# KBA13_SEG_OBERKLASSE          3  5
# SEMIO_VERT                    5  7
# KBA13_HALTER_20               3  2
# KBA13_KW_110                  2  3
# KBA13_FORD                    3  2
# KBA13_CCM_2500                3  5
# KBA05_MODTEMP                 3  1
# ARBEIT                        2  3
# PLZ8_ANTG2                    2  3
# RETOURTYP_BK_S                3  5
# KBA13_KW_70                   3  2
# REGIOTYP                      6  1
# KONSUMNAEHE                   5  3
# KBA13_OPEL                    3  2
# KBA13_HALTER_65               3  4
